# %% [markdown]
# # **Data 512: HW 1 - Professionalism & Reproducibility**
# The goal of this assignment is to construct, analyze, and publish datasets of monthly article traffic based on access type for a select set of pages from English Wikipedia from July 1, 2015 through September 30, 2024. The purpose of the assignment is to develop and follow best practices for open scientific research as exemplified by the repository. We are specifically focusing on a subset of the English Wikipedia articles that represents a large number of rear diseases which was collected from [National Organization for Rare Diseases (NORD)](https://rarediseases.org).

# %% [markdown]
# ## License
# Parts of the code below were taken as-is or with minimal changes from the example code that was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.3 - August 16, 2024

# %% [markdown]
# ## Part 1: Data Acquisition
#
# In this part, we will focus on gathering the data from the provided [Wikimedia Analytics API](https://doc.wikimedia.org/generated-data-platform/aqs/analytics-api/reference/page-views.html)  which provides us access to desktop, mobile app, and mobile web pageviews data. We specifically gather pageview data from July 1, 2015 - Sept 30, 2024, for the [specified diseases (article names)](./rare-disease_cleaned.AUG.2024.csv) and store them as JSON files.
#
# As part of this step, we will create 3 JSON Files:
# 1. Monthly mobile access - This will contain the monthly page traffic data for mobile web and mobile app.
#   - The output file will be called: rare-disease_monthly_mobile_201507-202409.json
#
# 2. Monthly desktop access - This will contain the data for monthly desktop page traffic.
#   - The output file will be called: rare-disease_monthly_desktop_201507-202409.json
#
# 3. Monthly cumulative - This will contain the monthly cumulative data of all mobile, and all desktop traffic per article.
#   - The output file will be called: rare-disease_monthly_cumulative_201507-202409.json

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Switching to the required folder (user might have to change in case trying to reproduce)
# %cd 'drive/MyDrive/Data 512/data-512-homework_1'
# Out:
# /content/drive/MyDrive/Data 512/data-512-homework_1

# %%
# These are standard python modules
import json, time, urllib.parse

# The 'requests' and 'pandas' module is not a standard Python module.
# You will need to install this with pip/pip3 if you do not already have it
import requests
import pandas as pd

# %% [markdown]
# We add all the required consants below to help with readability of the code. Note- You would need to change the email in request headers to ensure you get email in case of any issues.

# %%
#########
#
#    CONSTANTS
#

#
# The REST API 'pageviews' URL - this is the common URL/endpoint for all 'pageviews' API requests
API_REQUEST_PAGEVIEWS_ENDPOINT = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'

# This is a parameterized string that specifies what kind of pageviews request we are going to make
# In this case it will be a 'per-article' based request. The string is a format string so that we can
# replace each parameter with an appropriate value before making the request
API_REQUEST_PER_ARTICLE_PARAMS = 'per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}'

# The Pageviews API asks that we not exceed 100 requests per second, we add a small delay to each request
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making a request to the Wikimedia API they ask that you include your email address which will allow them
# to contact you if something happens - such as - your code exceeding rate limits - or some other error
REQUEST_HEADERS = {
    'User-Agent': '<gmihir@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2024',
}

# This template is used to map parameter values into the API_REQUST_PER_ARTICLE_PARAMS portion of an API request. The dictionary has a
# field/key for each of the required parameters. In the example, below, we only vary the article name, so the majority of the fields
# can stay constant for each request. Of course, these values *could* be changed if necessary.
ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_DESKTOP = {
    "project":     "en.wikipedia.org",
    "access":      "desktop",
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015070100",   # start and end dates need to be set
    "end":         "2024100100"
}

# Here we create templates for Mobile App and Mobile web by updating the "access" value in the Desktop template.
ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_MOBILEAPP = {
    **ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_DESKTOP,
    "access":      "mobile-app",
}

ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_MOBILEWEB = {
    **ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_DESKTOP,
    "access":      "mobile-web",
}

# %% [markdown]
# The API request will be made using one procedure. The idea is to make this reusable. The procedure is parameterized, but relies on the constants above for the important parameters. The underlying assumption is that this will be used to request data for a set of article pages. Therefore the parameter most likely to change is the article_title.

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageviews_per_article(article_title = None,
                                  endpoint_url = API_REQUEST_PAGEVIEWS_ENDPOINT,
                                  endpoint_params = API_REQUEST_PER_ARTICLE_PARAMS,
                                  request_template = ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_DESKTOP,
                                  headers = REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['article'] = article_title

    if not request_template['article']:
        raise Exception("Must supply an article title to make a pageviews request.")

    # Titles are supposed to have spaces replaced with "_" and be URL encoded
    # We also add safe='' to ensure '/' are read and encoded correctly
    article_title_encoded = urllib.parse.quote(request_template['article'].replace(' ','_'), safe='')
    request_template['article'] = article_title_encoded

    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)

    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# Now we load the rare disease data from a CSV file and initializes dictionaries to store the pageview data for desktop, mobile, and cumulative views.

# %%
# Read the list of rear diseases and corresponding wikipedia articles from the CSV file and create a dataframe
rear_disease_articles = pd.read_csv("./rare-disease_cleaned.AUG.2024.csv")

# Create empty dictionaries for each file to be created
desktop_views_dict = {}
mobile_views_dict = {}
cumulative_views_dict = {}

# %% [markdown]
# Here I have functions to fetch pageview data from the Wikipedia API for desktop and mobile views, as well as merge and calculate total views across devices for each rare disease.

# %%
# This function fetches pageviews and converts them into a DataFrame, dropping the "access" column
def fetch_pageviews(article_title, request_template):
    """
    This function fetches pageview data for a given Wikipedia article and converts it to a DataFrame.

    Args:
        article_title (str): The title of the Wikipedia article to fetch data for.
        request_template (dict): The request template with parameters for the API request.

    Returns:
        DataFrame: A pandas DataFrame containing the pageview data for the article with the "access" column dropped.
    """
    response = request_pageviews_per_article(article_title, request_template=request_template)
    data = response["items"]
    df = pd.DataFrame(data).drop('access', axis=1)  # Drop "access" column
    return df

# This function handles merging dataframes and calculating total views after the merge
def merge_and_calculate_views(df1, df2, view_col1, view_col2):
    """
    This function merges two DataFrames containing pageview data and calculates the total views by summing
    the values of two specified columns.

    Args:
        df1 (DataFrame): First DataFrame
        df2 (DataFrame): Second DataFrame
        view_col1 (str): The name of the view column in the first DataFrame.
        view_col2 (str): The name of the view column in the second DataFrame.

    Returns:
        DataFrame: A merged DataFrame with total views calculated and irrelevant columns dropped.
    """
    merged_df = pd.merge(df1, df2, on=["project", "article", "granularity", "timestamp", "agent"], how="outer")
    merged_df["views"] = merged_df[view_col1] + merged_df[view_col2]
    return merged_df.drop([view_col1, view_col2], axis=1)  # Drop the view columns to ensure only total views exist

# %% [markdown]
# Here the script fetches and merges the pageview data using the functions above for each disease in the dataset, calculates the cumulative views, and stores the results in separate JSON files for desktop, mobile, and total views.
#
# Note that, the following step takes about 45 minutes to run on Google Colab, as it goes through all the articles as mentioned in the dataset. You can choose to skip this step and directly start the analysis using the already generated JSON files which are stored in the "JSON Data Files" folder.

# %%
# The loop iterates over each row in the DataFrame and fetches pageviews for desktop and mobile, and then calculate cumulative views
for index, row in rear_disease_articles.iterrows():
    article_title = row["disease"]
    print(f"Processing pageview data for: {article_title} | index: {index}")

    # Fetch desktop views
    desktop_df = fetch_pageviews(article_title, ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_DESKTOP)
    desktop_views_dict[article_title] = desktop_df.to_dict(orient="records")
    print("Added Desktop views to dictionary")

    # Fetch mobile views (App and Web)
    mobile_app_df = fetch_pageviews(article_title, ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_MOBILEAPP)
    mobile_web_df = fetch_pageviews(article_title, ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE_MOBILEWEB)

    # Merge Mobile App and Web data
    mobile_df = merge_and_calculate_views(mobile_app_df, mobile_web_df, "views_x", "views_y")
    mobile_views_dict[article_title] = mobile_df.to_dict(orient="records")
    print("Added Mobile views to dictionary")

    # Calculate cumulative views by merging desktop and mobile data
    cumulative_df = merge_and_calculate_views(desktop_df, mobile_df, "views_x", "views_y")
    cumulative_views_dict[article_title] = cumulative_df.to_dict(orient="records")
    print("Added Cumulative views to dictionary")

    print("-x-x-x-x-x-x-x-")

# Ths function helps write dictionaries to JSON files
def write_to_json(data_dict, filename):
    """
    This function writes a dictionary to a specified JSON file.

    Args:
        data_dict (dict): The dictionary containing the data to be written to a JSON file.
        filename (str): The path of the JSON file to write to.

    Returns:
        None
    """
    try:
        with open(filename, "w") as f:
            json.dump(data_dict, f, ensure_ascii=False, indent=4)
    except Exception as e:
        print(f"Error writing {filename}: {e}")

# Save the dictionaries to the required JSON files
write_to_json(desktop_views_dict, "./JSON Data Files/rare-disease_monthly_desktop_201507-202409.json")
write_to_json(mobile_views_dict, "./JSON Data Files/rare-disease_monthly_mobile_201507-202409.json")
write_to_json(cumulative_views_dict, "./JSON Data Files/rare-disease_monthly_cumulative_201507-202409.json")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing pageview data for: Lambert–Eaton myasthenic syndrome | index: 773
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lamellar ichthyosis | index: 774
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Landau–Kleffner syndrome | index: 775
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Developmental regression | index: 776
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Langerhans cell histiocytosis | index: 777
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Canine histiocytic diseases | index: 778
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Eosinophilic granuloma | index: 779
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Letterer–Siwe disease | index: 780
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Larsen syndrome | index: 781
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Spasmodic dysphonia | index: 782
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Laurence–Moon syndrome | index: 783
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leber congenital amaurosis | index: 784
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: National Eye Institute | index: 785
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Legg–Calvé–Perthes disease | index: 786
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Legionnaires' disease | index: 787
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cruise ship | index: 788
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Windshield washer fluid | index: 789
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cooling tower | index: 790
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leigh syndrome | index: 791
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: MT-ATP6 | index: 792
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: SURF1 | index: 793
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: SERAC1 | index: 794
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Formylation | index: 795
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leiomyosarcoma | index: 796
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leishmaniasis | index: 797
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Visceral leishmaniasis | index: 798
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cutaneous leishmaniasis | index: 799
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Neglected tropical diseases | index: 800
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Miltefosine | index: 801
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lutzomyia | index: 802
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Refugee health | index: 803
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Transfusion transmitted infection | index: 804
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lennox–Gastaut syndrome | index: 805
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lamotrigine | index: 806
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Spike-and-wave | index: 807
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lenz microphthalmia syndrome | index: 808
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Donohue syndrome | index: 809
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leprosy | index: 810
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Hydnocarpus wightianus | index: 811
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leptospirosis | index: 812
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Manoa Falls | index: 813
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Globalization and disease | index: 814
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Dairy farming in New Zealand | index: 815
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Neil Carter (The Archers) | index: 816
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Joseph Vinetz | index: 817
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Beef cattle vaccination in Australia | index: 818
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Karl Friedrich Meyer | index: 819
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Feline zoonosis | index: 820
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leri pleonosteosis | index: 821
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lesch–Nyhan syndrome | index: 822
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Uric acid | index: 823
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: J. Edwin Seegmiller | index: 824
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Leukodystrophy | index: 825
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Li–Fraumeni syndrome | index: 826
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lichen planus | index: 827
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lichen sclerosus | index: 828
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Liposarcoma | index: 829
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Eribulin | index: 830
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lipoblast | index: 831
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lissencephaly | index: 832
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Gyrification | index: 833
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Neurotubule | index: 834
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Development of the cerebral cortex | index: 835
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Reelin | index: 836
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Listeriosis | index: 837
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Locked-in syndrome | index: 838
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Disorders of consciousness | index: 839
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Central nervous system disease | index: 840
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Long QT syndrome | index: 841
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Romano–Ward syndrome | index: 842
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Oculocerebrorenal syndrome | index: 843
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lymphangioleiomyomatosis | index: 844
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cystic hygroma | index: 845
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Microcystic lymphatic malformation | index: 846
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lymphangioma | index: 847
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lymphangioma circumscriptum | index: 848
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lymphangiomatosis | index: 849
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lymphedema–distichiasis syndrome | index: 850
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lymphomatoid granulomatosis | index: 851
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Diffuse large B-cell lymphoma | index: 852
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Infantile free sialic acid storage disease | index: 853
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Salla disease | index: 854
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Kifunensine | index: 855
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Machado–Joseph disease | index: 856
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Macroglossia | index: 857
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Oral and maxillofacial pathology | index: 858
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Benign symmetric lipomatosis | index: 859
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Maffucci syndrome | index: 860
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mal de debarquement | index: 861
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Malaria | index: 862
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Chloroquine | index: 863
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Eradication of infectious diseases | index: 864
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Primaquine | index: 865
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Tu Youyou | index: 866
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Sulfadoxine/pyrimethamine | index: 867
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Tropical medicine | index: 868
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Blood smear | index: 869
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Rebecca Akufo-Addo | index: 870
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Recrudescence | index: 871
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Malignant hyperthermia | index: 872
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Suxamethonium chloride | index: 873
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mallory–Weiss syndrome | index: 874
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mandibuloacral dysplasia | index: 875
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mantle cell lymphoma | index: 876
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Lenalidomide | index: 877
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Maple syrup urine disease | index: 878
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Protein (nutrient) | index: 879
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Marcus Gunn phenomenon | index: 880
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Marden–Walker syndrome | index: 881
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Marfan syndrome | index: 882
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Pleiotropy | index: 883
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Transforming growth factor beta | index: 884
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Fibrillin 1 | index: 885
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Health of Abraham Lincoln | index: 886
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Microfibril | index: 887
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Marinesco–Sjögren syndrome | index: 888
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Maroteaux–Lamy syndrome | index: 889
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Marshall–Smith syndrome | index: 890
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Marshall syndrome | index: 891
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mastocytosis | index: 892
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Histopathologic diagnosis of dermatitis | index: 893
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: May–Hegglin anomaly | index: 894
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: McCune–Albright syndrome | index: 895
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cartilage–hair hypoplasia | index: 896
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Allan–Herndon–Dudley syndrome | index: 897
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Measles | index: 898
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Social history of viruses | index: 899
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Meckel–Gruber syndrome | index: 900
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: MECP2 duplication syndrome | index: 901
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Median arcuate ligament syndrome | index: 902
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Medium-chain acyl-coenzyme A dehydrogenase deficiency | index: 903
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Medullary sponge kidney | index: 904
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Medulloblastoma | index: 905
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cyclin-dependent kinase 6 | index: 906
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Macrocephaly-capillary malformation | index: 907
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Pre-replication complex | index: 908
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Melanoma | index: 909
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Nivolumab | index: 910
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Ipilimumab | index: 911
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Vulvar cancer | index: 912
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Tremelimumab | index: 913
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: MELAS syndrome | index: 914
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mitochondrial myopathy | index: 915
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Encephalopathy | index: 916
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Meleda disease | index: 917
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Melkersson–Rosenthal syndrome | index: 918
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Facial nerve decompression | index: 919
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Orofacial granulomatosis | index: 920
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Melnick–Needles syndrome | index: 921
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Melorheostosis | index: 922
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Ménière's disease | index: 923
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Count Vertigo | index: 924
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Righting reflex | index: 925
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Endolymphatic hydrops | index: 926
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Meningioma | index: 927
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Crown (anatomy) | index: 928
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Falx cerebri | index: 929
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Sunitinib | index: 930
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Meningitis | index: 931
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Neonatal meningitis | index: 932
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Enterococcus | index: 933
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Procalcitonin | index: 934
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: PATH (global health organization) | index: 935
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Door handle bacteria | index: 936
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Alpha-mannosidosis | index: 937
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mannosidosis | index: 938
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mannosidase | index: 939
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Alport syndrome | index: 940
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Alström syndrome | index: 941
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Alternating hemiplegia of childhood | index: 942
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Alveolar capillary dysplasia | index: 943
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Alveolar soft part sarcoma | index: 944
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Hypersensitivity pneumonitis | index: 945
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Ameloblastic carcinoma | index: 946
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Ameloblastoma | index: 947
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Adamantinoma | index: 948
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Odontogenic tumor | index: 949
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Amelogenesis imperfecta | index: 950
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Acrania | index: 951
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Amniotic fluid embolism | index: 952
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Obstetric labor complication | index: 953
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Amyloidosis | index: 954
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: AA amyloidosis | index: 955
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: AL amyloidosis | index: 956
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Plasma cell dyscrasias | index: 957
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Diflunisal | index: 958
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Amyotrophic lateral sclerosis | index: 959
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Pseudobulbar affect | index: 960
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Neurodegenerative disease | index: 961
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Gliosis | index: 962
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Riluzole | index: 963
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Hemiballismus | index: 964
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Onuf's nucleus | index: 965
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Choline acetyltransferase | index: 966
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mecasermin rinfabate | index: 967
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cystine/glutamate transporter | index: 968
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Low-affinity nerve growth factor receptor | index: 969
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: RIPK1 | index: 970
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Avindra Nath | index: 971
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Neuroepigenetics | index: 972
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Anaplastic astrocytoma | index: 973
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Andersen–Tawil syndrome | index: 974
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Anemia of chronic disease | index: 975
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Autoimmune hemolytic anemia | index: 976
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Anemia | index: 977
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Folate deficiency | index: 978
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Tuberculous meningitis | index: 979
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Vaccination requirements for international travel | index: 980
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Meningococcal disease | index: 981
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Menkes disease | index: 982
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Copper in health | index: 983
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Merkel-cell carcinoma | index: 984
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: MERRF syndrome | index: 985
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bone sarcoma | index: 986
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mesothelioma | index: 987
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Paul Kraus | index: 988
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cappadocia | index: 989
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Asbestos-related diseases | index: 990
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Occupational lung disease | index: 991
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Metachromatic leukodystrophy | index: 992
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Sulfatide | index: 993
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Metaphyseal chondrodysplasia Schmid type | index: 994
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mevalonate kinase deficiency | index: 995
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Microvillus | index: 996
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Benign lymphoepithelial lesion | index: 997
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Miller syndrome | index: 998
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mixed connective tissue disease | index: 999
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cryoglobulinemic vasculitis | index: 1000
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: MOG antibody disease | index: 1001
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Monilethrix | index: 1002
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mowat–Wilson syndrome | index: 1003
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Moyamoya disease | index: 1004
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Pityriasis lichenoides et varioliformis acuta | index: 1005
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Muckle–Wells syndrome | index: 1006
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mucopolysaccharidosis | index: 1007
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Morquio syndrome | index: 1008
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mucopolysaccharidosis type I | index: 1009
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Hurler syndrome | index: 1010
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Hunter syndrome | index: 1011
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Sanfilippo syndrome | index: 1012
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Sly syndrome | index: 1013
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mucormycosis | index: 1014
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Zygomycosis | index: 1015
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mucous membrane pemphigoid | index: 1016
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mulibrey nanism | index: 1017
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Multifocal motor neuropathy | index: 1018
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Multiple endocrine neoplasia type 1 | index: 1019
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Multiple endocrine neoplasia type 2 | index: 1020
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Multiple myeloma | index: 1021
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: RANKL | index: 1022
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Syndecan | index: 1023
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Elotuzumab | index: 1024
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Osteoprotegerin | index: 1025
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Indatuximab ravtansine | index: 1026
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Mapatumumab | index: 1027
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Multiple sclerosis | index: 1028
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Autoimmune disease | index: 1029
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: TNF inhibitor | index: 1030
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: George Jelinek | index: 1031
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Euphoria | index: 1032
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Otilimab | index: 1033
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Dopamine | index: 1034
# Added Desktop views to dictionary
# ...
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Xeroderma pigmentosum | index: 1687
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: XPG N terminus | index: 1688
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: XYY syndrome | index: 1689
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Yaws | index: 1690
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Yellow fever | index: 1691
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Disease in colonial America | index: 1692
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Brown howler | index: 1693
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Stephen Girard | index: 1694
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: George Miller Sternberg | index: 1695
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Yellow nail syndrome | index: 1696
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Yunis–Varon syndrome | index: 1697
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Zellweger spectrum disorders | index: 1698
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Zollinger–Ellison syndrome | index: 1699
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Gastrinoma | index: 1700
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Atypical hemolytic uremic syndrome | index: 1701
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Factor H | index: 1702
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Ahus | index: 1703
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Auditory neuropathy spectrum disorder | index: 1704
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Auditory neuropathy | index: 1705
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Autoimmune hepatitis | index: 1706
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Spinocerebellar ataxia | index: 1707
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Episodic ataxia | index: 1708
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Autosomal dominant polycystic kidney disease | index: 1709
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Autosomal dominant porencephaly type I | index: 1710
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Polycystic kidney disease | index: 1711
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Autosomal recessive polycystic kidney disease | index: 1712
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Babesiosis | index: 1713
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Balantidiasis | index: 1714
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Baller–Gerold syndrome | index: 1715
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bannayan–Riley–Ruvalcaba syndrome | index: 1716
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Banti's syndrome | index: 1717
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Barakat syndrome | index: 1718
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bardet–Biedl syndrome | index: 1719
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Barth syndrome | index: 1720
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Tafazzin | index: 1721
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: 3-Methylglutaconic aciduria | index: 1722
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bartonellosis | index: 1723
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Carrion's disease | index: 1724
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Cat-scratch disease | index: 1725
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Self-experimentation in medicine | index: 1726
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Trench fever | index: 1727
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bartter syndrome | index: 1728
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Beckwith–Wiedemann syndrome | index: 1729
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Nonvenereal endemic syphilis | index: 1730
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Treponematosis | index: 1731
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bell's palsy | index: 1732
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Facial nerve paralysis | index: 1733
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Nancy Zieman | index: 1734
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Herpes simplex | index: 1735
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Rahul Sharma (cricketer, born 1986) | index: 1736
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: COVID-19 vaccine misinformation and hesitancy | index: 1737
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Blepharospasm | index: 1738
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Benign paroxysmal positional vertigo | index: 1739
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: DizzyFIX | index: 1740
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bernard–Soulier syndrome | index: 1741
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Giant platelet disorder | index: 1742
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Berylliosis | index: 1743
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Beryllium poisoning | index: 1744
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Vitelliform macular dystrophy | index: 1745
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Macular degeneration | index: 1746
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Beta thalassemia | index: 1747
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Biliary atresia | index: 1748
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Subcortical dementia | index: 1749
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Vascular dementia | index: 1750
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Biotinidase deficiency | index: 1751
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Multiple carboxylase deficiency | index: 1752
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Birt–Hogg–Dubé syndrome | index: 1753
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Björnstad syndrome | index: 1754
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Blastomycosis | index: 1755
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Blepharophimosis, ptosis, epicanthus inversus syndrome | index: 1756
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: FOXL2 | index: 1757
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bloom syndrome | index: 1758
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Blue diaper syndrome | index: 1759
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Blue rubber bleb nevus syndrome | index: 1760
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bohring–Opitz syndrome | index: 1761
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Botulism | index: 1762
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Canning | index: 1763
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Honey | index: 1764
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Flaccid paralysis | index: 1765
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Exogenous bacteria | index: 1766
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Frédéric Pagès | index: 1767
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bowen–Conradi syndrome | index: 1768
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bowenoid papulosis | index: 1769
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Branchio-oculo-facial syndrome | index: 1770
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Bronchopulmonary dysplasia | index: 1771
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-
# Processing pageview data for: Chronic lung disease | index: 1772
# Added Desktop views to dictionary
# Added Mobile views to dictionary
# Added Cumulative views to dictionary
# -x-x-x-x-x-x-x-

# %% [markdown]
# Now you have created the required three JSON files:
#
# 1. `rare-disease_monthly_mobile_201507-202409.json` - This contains the combined monthly page traffic data for mobile web and mobile app for the mentioned articles.
#
# 2. `rare-disease_monthly_desktop_201507-202409.json` - This contains the data for monthly desktop page traffic or the mentioned articles.
#
# 3. `rare-disease_monthly_cumulative_201507-202409.json` - This contains the monthly cumulative data of all mobile, and all desktop traffic per article or the mentioned articles.
#
# Next step is to analyse the data, and that can be done through the following notebook: [Wikipedia_Traffic_Analysis_Part2_DataAnalysis.ipynb](./Wikipedia_Traffic_Analysis_Part2_DataAnalysis.ipynb)
